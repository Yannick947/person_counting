# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_labels = pd.read_csv('C:/Users/Yannick/Google Drive/person_detection/pcds_dataset_detections/pcds_dataset_detected/pcds_dataset_labels_united.csv', names=['file_name', 'entering', 'exiting', 'video_class'])
df_labels.head()
# Out:
#                                            file_name  entering  exiting  \
# 0  front_in/normal/crowd/2016_04_07_19_23_49Front...         7        0
# 1  front_in/normal/crowd/2016_04_07_19_17_39Front...         5        0
# 2  front_in/normal/uncrowd/2016_04_07_19_13_02Fro...         1        0
# 3  front_in/normal/crowd/2016_04_07_19_09_56Front...        10        0
# 4  front_in/normal/crowd/2016_04_07_19_06_50Front...         6        0
#
#    video_class
# 0            1
# 1            1
# 2            0
# 3            1
# 4            1

# %%
df_labels.entering.hist()
plt.show()
df_labels.exiting.hist()
plt.show()
df_labels.video_class.hist()
plt.show()
