# %%
# %cd ..
# !nvidia-smi
# Out:
# Wed Sep  2 12:30:08 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.66       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    24W / 300W |      0MiB / 16130MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install gdown
# !pip install tensorflow-gpu==2.2 --user
# !pip install keras==2.3.1
# Out:
# ...
#      |████████████████████████████████| 516.2MB 29kB/s
# ...
#      |████████████████████████████████| 460kB 55.7MB/s
# ...
#      |████████████████████████████████| 3.0MB 49.5MB/s
# ...
# ERROR: tensorflow 2.3.0 has requirement tensorboard<3,>=2.3.0, but you'll have tensorboard 2.2.2 which is incompatible.
# ERROR: tensorflow 2.3.0 has requirement tensorflow-estimator<2.4.0,>=2.3.0, but you'll have tensorflow-estimator 2.2.0 which is incompatible.
# ...
#   WARNING: The script tensorboard is installed in '/root/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts estimator_ckpt_converter, saved_model_cli, tensorboard, tf_upgrade_v2, tflite_convert, toco and toco_from_protos are installed in '/root/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...

# %% [markdown]
# # Imports

# %%
from pandas.plotting import register_matplotlib_converters
import seaborn as sns
from matplotlib import rc
from pylab import rcParams
from IPython.display import Image
import os 
from datetime import datetime

# %matplotlib notebook
# %config InlineBackend.figure_format='retina'

register_matplotlib_converters()
sns.set(style='whitegrid', palette='muted', font_scale=1.5)

rcParams['figure.figsize'] = 22, 10
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # Training

# %%
logdir = '/content/drive/My\ Drive/person_counting/tensorboard/cnn_regression/cold_start/t1_{}'.format(datetime.now().strftime("%Y-%m-%d-%H-%M-%S"))
top_path = '/content/drive/My\ Drive/person_detection/pcds_dataset_detections/pcds_dataset_detected/'

# %%
# %cd /content/drive/My\ Drive/
# Out:
# /content/drive/My Drive

# %%
# !python -m person_counting.models.cnn_regression  --topdir-log {logdir}\
                                                  --n-runs 100 \
                                                  --augmentation-factor 0\
                                                  --filter-hour-above 21\
                                                  --top-path {top_path}\
                                                  --epochs 120\
                                                  --schedule-step 35\
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# 2020-09-02 12:26:09.251124: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-09-02 12:26:09.316478: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-02 12:26:09.317141: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla V100-SXM2-16GB computeCapability: 7.0
# coreClock: 1.53GHz coreCount: 80 deviceMemorySize: 15.75GiB deviceMemoryBandwidth: 836.37GiB/s
# ...

# %% [markdown]
# #Training the best configuration and save some visualization
#
# Set the params for best configuration in the test_cnn.py file

# %%
# !python -m person_counting.tests.test_cnn train_best_gpu

# %% [markdown]
# # Visualization of last runs

# %%
for root, _, files in os.walk(logdir):
  for file_name in files:
    if image_name[-4:] == '.png':
      Image(os.path.join(image_path, image_name))

# %% [markdown]
# #Utils

# %%
# use this code to prevent colab from disconnecting during longer training times in javascript console window (not in colab cell)
function ClickConnect(){
    console.log("Clicked on connect button"); 
    document.querySelector("colab-connect-button").click()
}
setInterval(ClickConnect, 60000)
