# %%
# %cd ..
# !nvidia-smi
# Out:
# Sun Jul 12 15:21:20 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.36.06    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install gdown
# !pip install tensorflow-gpu --user
# !pip install keras==2.3.1
# !pip install ann_visualizer
# !pip install graphviz
# Out:
# ...
#      |████████████████████████████████| 516.2MB 32kB/s
# ...
#   WARNING: The scripts estimator_ckpt_converter, saved_model_cli, tensorboard, tf_upgrade_v2, tflite_convert, toco and toco_from_protos are installed in '/root/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...
#   Created wheel for ann-visualizer: filename=ann_visualizer-2.5-cp36-none-any.whl size=4169 sha256=098873922b2fe5610b3ed418f1b567b1a5dd2fdd4266c2349f35d3dc4f1f7792
#   Stored in directory: /root/.cache/pip/wheels/b6/b4/4e/d92f50c9c4f004cf315a0e0fcd455486bd799c50fe80cf1f5d
# Successfully built ann-visualizer
# ...

# %% [markdown]
# # Training

# %%
from datetime import datetime

logdir = '/content/drive/My\ Drive/person_counting/tensorboard/cnn_regression/cold_start/t2_{}'.format(datetime.now().strftime("%Y-%m-%d-%H-%M-%S"))
top_path = '/content/drive/My\ Drive/person_detection/pcds_dataset_detections/pcds_dataset_detected/'
snap = '/content/drive/My\ Drive/person_counting/tensorboard/cnn_regression/full_data_third/t2_2020-07-06-06-41-02_cnn_2020_Jul_06_11_06_00'

# %%
# %cd /content/drive/My\ Drive/
# Out:
# /content/drive/My Drive

# %%
# !python -m person_counting.models.cnn_regression  --topdir-log {logdir}\
                                                  --n-runs 20 \
                                                  --schedule-step 35\
                                                  --augmentation-factor 0\
                                                  --filter-hour-above 20\
                                                  --top-path {top_path}\
                                                  --epochs 120\
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# 2020-07-12 15:23:21.268238: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-07-12 15:23:21.310432: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-07-12 15:23:21.311069: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# ...

# %% [markdown]
# # Testing for best params
#
# ### Set static params in test file

# %%
from pandas.plotting import register_matplotlib_converters
import seaborn as sns
from matplotlib import rc
from pylab import rcParams

import matplotlib.pyplot as plt
# %matplotlib inline

plt.style.use('classic')

# !python -m person_counting.tests.test_lstm train_best_gpu
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# Using TensorFlow backend.
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/content/drive/My Drive/person_counting/tests/test_lstm.py", line 95, in <module>
#     main()
#   File "/content/drive/My Drive/person_counting/tests/test_lstm.py", line 35, in main
#     train_best(workers, multi_processing, top_path)
# ...

# %%
# use this code to prevent colab from disconnecting during longer training times in javascript console window
function ClickConnect(){
    console.log("Clicked on connect button"); 
    document.querySelector("colab-connect-button").click()
}
setInterval(ClickConnect,60000)
# Out:
#   File "<ipython-input-9-b920829e6d25>", line 2
#     function ClickConnect(){
#                         ^
# SyntaxError: invalid syntax
