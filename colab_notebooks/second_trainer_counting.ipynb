# %%
# %cd ..
# !nvidia-smi
# Out:
# Fri Apr 24 14:35:51 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.64.00    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   51C    P0    31W / 250W |      0MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip install gdown
# !pip install tensorflow-gpu --user
# !pip install --upgrade keras
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.6/dist-packages (3.6.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from gdown) (2.21.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from gdown) (1.12.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from gdown) (4.38.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->gdown) (2020.4.5.1)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->gdown) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->gdown) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->gdown) (1.24.3)
# Requirement already satisfied: tensorflow-gpu in /root/.local/lib/python3.6/site-packages (2.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (1.12.0)
# Requirement already satisfied: keras-preprocessing>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (1.1.0)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (3.10.0)
# Requirement already satisfied: gast==0.2.2 in /root/.local/lib/python3.6/site-packages (from tensorflow-gpu) (0.2.2)
# Requirement already satisfied: scipy==1.4.1; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (1.4.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (1.1.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (1.12.1)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (0.34.2)
# Requirement already satisfied: tensorboard<2.2.0,>=2.1.0 in /root/.local/lib/python3.6/site-packages (from tensorflow-gpu) (2.1.1)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (1.0.8)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (0.8.1)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (1.18.2)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (1.28.1)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (0.2.0)
# Requirement already satisfied: tensorflow-estimator<2.2.0,>=2.1.0rc0 in /root/.local/lib/python3.6/site-packages (from tensorflow-gpu) (2.1.0)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (0.9.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (3.2.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.8.0->tensorflow-gpu) (46.1.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (0.4.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (1.7.2)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (3.2.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (2.21.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.8->tensorflow-gpu) (2.10.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (1.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (0.2.8)
# Requirement already satisfied: cachetools<3.2,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (3.1.1)
# Requirement already satisfied: rsa<4.1,>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (4.0)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (1.24.3)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (2020.4.5.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (3.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (3.1.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.6/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (0.4.8)
# Requirement already up-to-date: keras in /usr/local/lib/python3.6/dist-packages (2.3.1)
# Requirement already satisfied, skipping upgrade: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras) (1.1.0)
# Requirement already satisfied, skipping upgrade: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras) (3.13)
# Requirement already satisfied, skipping upgrade: h5py in /usr/local/lib/python3.6/dist-packages (from keras) (2.10.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras) (1.18.2)
# Requirement already satisfied, skipping upgrade: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras) (1.4.1)
# Requirement already satisfied, skipping upgrade: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from keras) (1.0.8)
# Requirement already satisfied, skipping upgrade: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras) (1.12.0)

# %%
#quickfix error in callbacks of keras, pullrequest is already open in github
#later versions of tensorflow and keras should contain this fix
# %cd ../../../../../../
from google.colab import files
import shutil
# %cd root/.local/lib/python3.6/site-packages/tensorflow_core/python/keras/
# files.download('callbacks.py')
# !rm callbacks.py
shutil.copyfile('/content/drive/My Drive/person_detection/utils/callbacks.py', 
                './callbacks.py')
# !ls
# Out:
# /
# /root/.local/lib/python3.6/site-packages/tensorflow_core/python/keras
# rm: cannot remove 'callbacks.py': No such file or directory
# activations.py	   estimator			   optimizers.py
# api		   initializers.py		   optimizer_v2
# applications	   __init__.py			   premade
# backend_config.py  keras_parameterized.py	   preprocessing
# backend.py	   layers			   __pycache__
# callbacks.py	   losses.py			   regularizers.py
# callbacks_v1.py    metrics.py			   saving
# constraints.py	   mixed_precision		   testing_utils.py
# datasets	   models.py			   utils
# distribute	   model_subclassing_test_util.py  wrappers
# engine		   ops.py

# %% [markdown]
# # Training

# %%
from datetime import datetime

logdir = '/content/drive/My\ Drive/person_counting/tensorboard/colab_{}_trainer_nr_2/'.format(datetime.now().strftime("%Y-%m-%d-%H-%M-%S"))
top_path = '/content/drive/My\ Drive/person_detection/bus_videos/pcds_dataset_detected/'

# %%
# %cd /content/drive/My\ Drive/
# Out:
# /content/drive/My Drive

# %%
# !python -m person_counting.models.cnn_regression --topdir-log {logdir} \
                                                 --n-runs 100 \
                                                 --top-path {top_path}\
                                                 --batch-size 8\
                                                 --filter-rows-factor 1
# Out:
# Using TensorFlow backend.
# 2020-04-24 21:19:42.851670: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer.so.6'; dlerror: libnvinfer.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2020-04-24 21:19:42.851789: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer_plugin.so.6'; dlerror: libnvinfer_plugin.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2020-04-24 21:19:42.851809: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:30] Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Dataset contains:
# 0 training csvs
# 0 testing csvs
# [1.57445582e-04 3.17561051e-02 4.23590071e-03 1.24052049e-03
#  2.10399433e-05 2.10352698e-05 8.53698372e-06 1.45772159e-02
#  1.26890775e-03 3.39828905e-03]
# 2020-04-24 21:19:44.777407: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-04-24 21:19:44.793493: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-24 21:19:44.794384: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1555] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2020-04-24 21:19:44.794760: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-04-24 21:19:44.797616: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-04-24 21:19:44.801049: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-04-24 21:19:44.801607: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-04-24 21:19:44.805353: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-04-24 21:19:44.806618: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-04-24 21:19:44.812659: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-04-24 21:19:44.812798: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-24 21:19:44.813892: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-24 21:19:44.814735: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1697] Adding visible gpu devices: 0
# 2020-04-24 21:19:44.815119: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2020-04-24 21:19:44.820179: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2020-04-24 21:19:44.820628: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x27b44c0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-04-24 21:19:44.820671: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-04-24 21:19:44.915749: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-24 21:19:44.916923: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x27b4d80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-04-24 21:19:44.917021: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 2020-04-24 21:19:44.917319: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-24 21:19:44.918201: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1555] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2020-04-24 21:19:44.918273: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-04-24 21:19:44.918304: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-04-24 21:19:44.918345: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-04-24 21:19:44.918380: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-04-24 21:19:44.918411: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-04-24 21:19:44.918437: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-04-24 21:19:44.918464: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-04-24 21:19:44.918564: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-24 21:19:44.919548: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-24 21:19:44.920456: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1697] Adding visible gpu devices: 0
# 2020-04-24 21:19:44.920522: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-04-24 21:19:44.922349: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1096] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-04-24 21:19:44.922383: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1102]      0
# 2020-04-24 21:19:44.922392: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] 0:   N
# 2020-04-24 21:19:44.922619: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-24 21:19:44.923672: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-24 21:19:44.924616: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-04-24 21:19:44.924671: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1241] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15216 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# Tried to create a MaxPool Layer that is not possible to create, because it would lead to negative dimensions. Creation was skipped
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 524, 64, 3)        150
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 131, 16, 3)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 131, 16, 3)        12
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 125, 10, 3)        444
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 31, 2, 3)          0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 31, 2, 3)          12
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 186)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 187
# =================================================================
# Total params: 805
# Trainable params: 793
# Non-trainable params: 12
# _________________________________________________________________
# Actual model is using following hyper-parameters:
# y_stride :  1
# optimizer :  Adam
# max_pool_size :  4
# learning_rate :  1.3885067726533708e-05
# layer_number :  3
# kernel_size :  7
# kernel_number :  3
# batch_normalization :  True
# filter_cols :  5
# batch_size :  8
# filter_cols_factor :  1
# filter_rows_factor :  1
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_generator.py:49: UserWarning: Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence class.
#   UserWarning('Using a generator with `use_multiprocessing=True`'
# Epoch 1/12
# 2020-04-24 21:19:54.208467: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-04-24 21:19:54.487658: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 92/92 [==============================] - 32s 344ms/step - loss: 0.3696 - val_loss: 0.2121
# Epoch 2/12
# 92/92 [==============================] - 25s 273ms/step - loss: 0.3035 - val_loss: 0.2117
# Epoch 3/12
# 92/92 [==============================] - 27s 288ms/step - loss: 0.2717 - val_loss: 0.2054
# Epoch 4/12
# 92/92 [==============================] - 24s 265ms/step - loss: 0.2051 - val_loss: 0.1603
# Epoch 5/12
# 92/92 [==============================] - 26s 285ms/step - loss: 0.2260 - val_loss: 0.2061
# Epoch 6/12
# 92/92 [==============================] - 27s 291ms/step - loss: 0.1847 - val_loss: 0.1037
# Epoch 7/12
# 92/92 [==============================] - 27s 291ms/step - loss: 0.1353 - val_loss: 0.1118
# Epoch 8/12
# 92/92 [==============================] - 27s 292ms/step - loss: 0.1699 - val_loss: 0.1793
# Epoch 9/12
# 92/92 [==============================] - 27s 293ms/step - loss: 0.1648 - val_loss: 0.1077
# Epoch 10/12
# 92/92 [==============================] - 27s 291ms/step - loss: 0.1518 - val_loss: 0.1170
# Epoch 11/12
# 92/92 [==============================] - 26s 284ms/step - loss: 0.0979 - val_loss: 0.0739
# Epoch 12/12
# 92/92 [==============================] - 25s 267ms/step - loss: 0.1170 - val_loss: 0.1304
# Tried to create a MaxPool Layer that is not possible to create, because it would lead to negative dimensions. Creation was skipped
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 263, 66, 5)        130
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 65, 16, 5)         0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 65, 16, 5)         20
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 31, 12, 5)         630
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 7, 3, 5)           0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 7, 3, 5)           20
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 105)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 106
# =================================================================
# Total params: 906
# Trainable params: 886
# Non-trainable params: 20
# _________________________________________________________________
# Actual model is using following hyper-parameters:
# y_stride :  2
# optimizer :  Adam
# max_pool_size :  4
# learning_rate :  0.00810540331268768
# layer_number :  3
# kernel_size :  5
# kernel_number :  5
# batch_normalization :  True
# filter_cols :  5
# batch_size :  8
# filter_cols_factor :  1
# filter_rows_factor :  1
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_generator.py:49: UserWarning: Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence class.
#   UserWarning('Using a generator with `use_multiprocessing=True`'
# Epoch 1/12
# 92/92 [==============================] - 30s 329ms/step - loss: 0.0084 - val_loss: 0.0023
# Epoch 2/12
# 92/92 [==============================] - 27s 289ms/step - loss: 0.0019 - val_loss: 0.0012
# Epoch 3/12
# 92/92 [==============================] - 23s 251ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 4/12
# 92/92 [==============================] - 27s 298ms/step - loss: 8.8384e-04 - val_loss: 0.0019
# Epoch 5/12
# 92/92 [==============================] - 27s 292ms/step - loss: 5.5282e-04 - val_loss: 0.0011
# Epoch 6/12
# 92/92 [==============================] - 26s 281ms/step - loss: 0.0013 - val_loss: 0.0019
# Epoch 7/12
# 92/92 [==============================] - 27s 296ms/step - loss: 6.7294e-04 - val_loss: 5.1336e-04
# Epoch 8/12
# 92/92 [==============================] - 28s 307ms/step - loss: 6.5972e-04 - val_loss: 0.0013
# Epoch 9/12
# 92/92 [==============================] - 26s 278ms/step - loss: 5.4514e-04 - val_loss: 0.0030
# Epoch 10/12
# 92/92 [==============================] - 27s 293ms/step - loss: 5.9839e-04 - val_loss: 0.0017
# Epoch 11/12
# 92/92 [==============================] - 26s 286ms/step - loss: 2.8580e-04 - val_loss: 6.1396e-05
# Epoch 12/12
# 92/92 [==============================] - 25s 274ms/step - loss: 3.5383e-04 - val_loss: 1.7738e-04
# Tried to create a MaxPool Layer that is not possible to create, because it would lead to negative dimensions. Creation was skipped
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_7 (Conv2D)            (None, 262, 64, 3)        150
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 87, 21, 3)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 41, 15, 3)         444
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 13, 5, 3)          0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 195)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 196
# =================================================================
# Total params: 790
# Trainable params: 790
# Non-trainable params: 0
# _________________________________________________________________
# Actual model is using following hyper-parameters:
# y_stride :  2
# optimizer :  Adam
# max_pool_size :  3
# learning_rate :  6.520202557320308e-05
# layer_number :  3
# kernel_size :  7
# kernel_number :  3
# batch_normalization :  False
# filter_cols :  5
# batch_size :  8
# filter_cols_factor :  1
# filter_rows_factor :  1
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_generator.py:49: UserWarning: Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence class.
#   UserWarning('Using a generator with `use_multiprocessing=True`'
# Epoch 1/12
# 92/92 [==============================] - 30s 325ms/step - loss: 0.2106 - val_loss: 0.1894
# Epoch 2/12
# 92/92 [==============================] - 24s 263ms/step - loss: 0.1775 - val_loss: 0.1543
# Epoch 3/12
# 92/92 [==============================] - 24s 264ms/step - loss: 0.1172 - val_loss: 0.0906
# Epoch 4/12
# 92/92 [==============================] - 27s 295ms/step - loss: 0.0572 - val_loss: 0.0478
# Epoch 5/12
# 92/92 [==============================] - 28s 300ms/step - loss: 0.0299 - val_loss: 0.0157
# Epoch 6/12
# 92/92 [==============================] - 27s 294ms/step - loss: 0.0138 - val_loss: 0.0089
# Epoch 7/12
# 92/92 [==============================] - 26s 287ms/step - loss: 0.0066 - val_loss: 0.0065
# Epoch 8/12
# 92/92 [==============================] - 29s 313ms/step - loss: 0.0037 - val_loss: 0.0029
# Epoch 9/12
# 92/92 [==============================] - 25s 271ms/step - loss: 0.0037 - val_loss: 0.0015
# Epoch 10/12
# 92/92 [==============================] - 27s 298ms/step - loss: 0.0023 - val_loss: 0.0020
# Epoch 11/12
# 92/92 [==============================] - 28s 301ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 12/12
# 92/92 [==============================] - 24s 261ms/step - loss: 0.0020 - val_loss: 0.0011
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_10 (Conv2D)           (None, 262, 63, 7)        455
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 65, 15, 7)         0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 65, 15, 7)         28
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 29, 8, 7)          3143
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 7, 2, 7)           0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 98)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 99
# =================================================================
# Total params: 3,725
# Trainable params: 3,711
# Non-trainable params: 14
# _________________________________________________________________
# Actual model is using following hyper-parameters:
# y_stride :  2
# optimizer :  Adam
# max_pool_size :  4
# learning_rate :  0.00016201304634928993
# layer_number :  2
# kernel_size :  8
# kernel_number :  7
# batch_normalization :  True
# filter_cols :  5
# batch_size :  8
# filter_cols_factor :  1
# filter_rows_factor :  1
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_generator.py:49: UserWarning: Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence class.
#   UserWarning('Using a generator with `use_multiprocessing=True`'
# Epoch 1/12
# 92/92 [==============================] - 30s 331ms/step - loss: 0.1746 - val_loss: 0.1681
# Epoch 2/12
# 92/92 [==============================] - 26s 283ms/step - loss: 0.0138 - val_loss: 0.1130
# Epoch 3/12
# 92/92 [==============================] - 24s 264ms/step - loss: 0.0040 - val_loss: 0.0543
# Epoch 4/12
# 92/92 [==============================] - 26s 280ms/step - loss: 0.0045 - val_loss: 0.0272
# Epoch 5/12
# 92/92 [==============================] - 27s 292ms/step - loss: 0.0032 - val_loss: 0.0133
# Epoch 6/12
# 92/92 [==============================] - 27s 291ms/step - loss: 0.0099 - val_loss: 0.0034
# Epoch 7/12
# 92/92 [==============================] - 26s 286ms/step - loss: 0.0200 - val_loss: 0.0767
# Epoch 8/12
# 92/92 [==============================] - 27s 295ms/step - loss: 0.0023 - val_loss: 0.0029
# Epoch 9/12
# 92/92 [==============================] - 25s 267ms/step - loss: 0.0031 - val_loss: 0.0016
# Epoch 10/12
# 92/92 [==============================] - 28s 303ms/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 11/12
# 92/92 [==============================] - 27s 292ms/step - loss: 0.0195 - val_loss: 6.4069e-04
# Epoch 12/12
# 92/92 [==============================] - 24s 265ms/step - loss: 0.0019 - val_loss: 0.0021
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 527, 67, 9)        153
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 131, 16, 9)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 128, 13, 9)        1305
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 32, 3, 9)          0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 864)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 865
# =================================================================
# Total params: 2,323
# Trainable params: 2,323
# Non-trainable params: 0
# _________________________________________________________________
# Actual model is using following hyper-parameters:
# y_stride :  1
# optimizer :  Adam
# max_pool_size :  4
# learning_rate :  0.0021051848318983713
# layer_number :  2
# kernel_size :  4
# kernel_number :  9
# batch_normalization :  False
# filter_cols :  5
# batch_size :  8
# filter_cols_factor :  1
# filter_rows_factor :  1
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_generator.py:49: UserWarning: Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence class.
#   UserWarning('Using a generator with `use_multiprocessing=True`'
# Epoch 1/12
# 92/92 [==============================] - 33s 356ms/step - loss: 0.0189 - val_loss: 0.0036
# Epoch 2/12
# 92/92 [==============================] - 23s 252ms/step - loss: 0.0022 - val_loss: 0.0024
# Epoch 3/12
# 92/92 [==============================] - 26s 278ms/step - loss: 0.0018 - val_loss: 0.0035
# Epoch 4/12
# 92/92 [==============================] - 26s 285ms/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 5/12
# 92/92 [==============================] - 26s 288ms/step - loss: 0.0024 - val_loss: 0.0042
# Epoch 6/12
# 92/92 [==============================] - 26s 284ms/step - loss: 0.0024 - val_loss: 0.0013
# Epoch 7/12
# 92/92 [==============================] - 24s 263ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 8/12
# 92/92 [==============================] - 25s 275ms/step - loss: 7.1144e-04 - val_loss: 7.7123e-04
# Epoch 9/12
# 92/92 [==============================] - 25s 276ms/step - loss: 1.3502e-04 - val_loss: 3.5208e-04
# Epoch 10/12
# 92/92 [==============================] - 25s 276ms/step - loss: 3.2628e-04 - val_loss: 3.1390e-04
# Epoch 11/12
# 92/92 [==============================] - 28s 309ms/step - loss: 2.0601e-04 - val_loss: 1.9736e-04
# Epoch 12/12
# 92/92 [==============================] - 26s 283ms/step - loss: 1.6490e-04 - val_loss: 7.8907e-04
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_14 (Conv2D)           (None, 264, 67, 8)        136
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 66, 16, 8)         0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 32, 13, 8)         1032
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 8, 3, 8)           0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 192)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 193
# =================================================================
# Total params: 1,361
# Trainable params: 1,361
# Non-trainable params: 0
# _________________________________________________________________
# Actual model is using following hyper-parameters:
# y_stride :  2
# optimizer :  RMSProp
# max_pool_size :  4
# learning_rate :  0.003866191056649883
# layer_number :  2
# kernel_size :  4
# kernel_number :  8
# batch_normalization :  False
# filter_cols :  5
# batch_size :  8
# filter_cols_factor :  1
# filter_rows_factor :  1
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_generator.py:49: UserWarning: Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence class.
#   UserWarning('Using a generator with `use_multiprocessing=True`'
# Epoch 1/12
# 92/92 [==============================] - 31s 335ms/step - loss: 0.0057 - val_loss: 2.3419e-04
# Epoch 2/12
# 92/92 [==============================] - 25s 267ms/step - loss: 3.4332e-04 - val_loss: 1.6551e-04
# Epoch 3/12
# 92/92 [==============================] - 24s 260ms/step - loss: 3.7087e-04 - val_loss: 9.8381e-04
# Epoch 4/12
# 92/92 [==============================] - 27s 288ms/step - loss: 2.7910e-04 - val_loss: 0.0011
# Epoch 5/12
# 92/92 [==============================] - 27s 293ms/step - loss: 3.0336e-04 - val_loss: 2.1910e-04
# Epoch 6/12
# 92/92 [==============================] - 27s 291ms/step - loss: 2.7704e-04 - val_loss: 2.1581e-04
# Epoch 7/12
# 92/92 [==============================] - 26s 283ms/step - loss: 2.9573e-04 - val_loss: 3.8644e-04
# Epoch 8/12
# 92/92 [==============================] - 28s 309ms/step - loss: 2.6105e-04 - val_loss: 1.7384e-04
# Epoch 9/12
# 92/92 [==============================] - 26s 286ms/step - loss: 2.5710e-04 - val_loss: 8.6144e-04
# Epoch 10/12
# 92/92 [==============================] - 26s 278ms/step - loss: 2.4916e-04 - val_loss: 7.1180e-04
# Epoch 11/12
# 92/92 [==============================] - 27s 295ms/step - loss: 2.1855e-04 - val_loss: 0.0013
# Epoch 12/12
# 92/92 [==============================] - 25s 272ms/step - loss: 1.5496e-04 - val_loss: 1.4516e-04
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_16 (Conv2D)           (None, 523, 63, 7)        455
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 130, 15, 7)        0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 123, 8, 7)         3143
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 30, 2, 7)          0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 420)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 421
# =================================================================
# Total params: 4,019
# Trainable params: 4,019
# Non-trainable params: 0
# _________________________________________________________________
# Actual model is using following hyper-parameters:
# y_stride :  1
# optimizer :  RMSProp
# max_pool_size :  4
# learning_rate :  0.007678363732329449
# layer_number :  2
# kernel_size :  8
# kernel_number :  7
# batch_normalization :  False
# filter_cols :  5
# batch_size :  8
# filter_cols_factor :  1
# filter_rows_factor :  1
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_generator.py:49: UserWarning: Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence class.
#   UserWarning('Using a generator with `use_multiprocessing=True`'
# Epoch 1/12
# 92/92 [==============================] - 31s 334ms/step - loss: 0.0047 - val_loss: 0.0022
# Epoch 2/12
# 92/92 [==============================] - 24s 266ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 3/12
# 92/92 [==============================] - 26s 286ms/step - loss: 0.0102 - val_loss: 0.0015
# Epoch 4/12
# 92/92 [==============================] - 26s 281ms/step - loss: 0.0026 - val_loss: 0.0021
# Epoch 5/12
# 92/92 [==============================] - 26s 281ms/step - loss: 0.0041 - val_loss: 0.0023
# Epoch 6/12
# 92/92 [==============================] - 27s 291ms/step - loss: 0.0124 - val_loss: 0.0024
# Epoch 7/12
# 92/92 [==============================] - 25s 277ms/step - loss: 0.0018 - val_loss: 0.0034
# Epoch 8/12
# 92/92 [==============================] - 29s 310ms/step - loss: 0.0023 - val_loss: 0.0032
# Epoch 9/12
# 92/92 [==============================] - 26s 280ms/step - loss: 0.0066 - val_loss: 0.0040
# Epoch 10/12
# 92/92 [==============================] - 26s 285ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 11/12
# 92/92 [==============================] - 28s 306ms/step - loss: 7.0884e-04 - val_loss: 2.2930e-04
# Epoch 12/12
# 92/92 [==============================] - 24s 261ms/step - loss: 0.0011 - val_loss: 0.0020
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_18 (Conv2D)           (None, 262, 63, 5)        325
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 131, 31, 5)        0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 62, 24, 5)         1605
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 31, 12, 5)         0
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 1860)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 1861
# =================================================================
# Total params: 3,791
# Trainable params: 3,791
# Non-trainable params: 0
# _________________________________________________________________
# Actual model is using following hyper-parameters:
# y_stride :  2
# optimizer :  Adam
# max_pool_size :  2
# learning_rate :  7.803532954683548e-05
# layer_number :  2
# kernel_size :  8
# kernel_number :  5
# batch_normalization :  False
# filter_cols :  5
# batch_size :  8
# filter_cols_factor :  1
# filter_rows_factor :  1
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_generator.py:49: UserWarning: Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence class.
#   UserWarning('Using a generator with `use_multiprocessing=True`'
# Epoch 1/12
# 92/92 [==============================] - 34s 367ms/step - loss: 0.1776 - val_loss: 0.0809
# Epoch 2/12
# 92/92 [==============================] - 24s 263ms/step - loss: 0.0275 - val_loss: 0.0047
# Epoch 3/12
# 92/92 [==============================] - 23s 253ms/step - loss: 0.0027 - val_loss: 0.0011
# Epoch 4/12
# 92/92 [==============================] - 27s 291ms/step - loss: 0.0016 - val_loss: 0.0011
# Epoch 5/12
# 92/92 [==============================] - 26s 281ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 6/12
# 92/92 [==============================] - 27s 289ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 7/12
# 92/92 [==============================] - 26s 279ms/step - loss: 0.0014 - val_loss: 6.2057e-04
# Epoch 8/12
# 92/92 [==============================] - 27s 289ms/step - loss: 0.0016 - val_loss: 0.0026
# Epoch 9/12
# 92/92 [==============================] - 26s 284ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 10/12
# 92/92 [==============================] - 28s 299ms/step - loss: 0.0016 - val_loss: 0.0023
# Epoch 11/12
# 92/92 [==============================] - 28s 305ms/step - loss: 9.1133e-04 - val_loss: 0.0024
# Epoch 12/12
# 92/92 [==============================] - 25s 273ms/step - loss: 8.3118e-04 - val_loss: 6.1887e-04
# Tried to create a MaxPool Layer that is not possible to create, because it would lead to negative dimensions. Creation was skipped
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_20 (Conv2D)           (None, 524, 64, 4)        200
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 131, 16, 4)        0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 125, 10, 4)        788
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 31, 2, 4)          0
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 248)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 249
# =================================================================
# Total params: 1,237
# Trainable params: 1,237
# Non-trainable params: 0
# _________________________________________________________________
# Actual model is using following hyper-parameters:
# y_stride :  1
# optimizer :  Adam
# max_pool_size :  4
# learning_rate :  2.2708853184312736e-05
# layer_number :  3
# kernel_size :  7
# kernel_number :  4
# batch_normalization :  False
# filter_cols :  5
# batch_size :  8
# filter_cols_factor :  1
# filter_rows_factor :  1
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_generator.py:49: UserWarning: Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence class.
#   UserWarning('Using a generator with `use_multiprocessing=True`'
# Epoch 1/12
# 92/92 [==============================] - 32s 342ms/step - loss: 0.2442 - val_loss: 0.2301
# Epoch 2/12
# 92/92 [==============================] - 26s 285ms/step - loss: 0.2317 - val_loss: 0.2325
# Epoch 3/12
# 92/92 [==============================] - 25s 272ms/step - loss: 0.2166 - val_loss: 0.2073
# Epoch 4/12
# 92/92 [==============================] - 27s 293ms/step - loss: 0.2017 - val_loss: 0.1928
# Epoch 5/12
# 92/92 [==============================] - 26s 287ms/step - loss: 0.1825 - val_loss: 0.1721
# Epoch 6/12
# 92/92 [==============================] - 27s 291ms/step - loss: 0.1547 - val_loss: 0.1355
# Epoch 7/12
# 92/92 [==============================] - 25s 276ms/step - loss: 0.1353 - val_loss: 0.1332
# Epoch 8/12
# 92/92 [==============================] - 26s 283ms/step - loss: 0.1032 - val_loss: 0.1029
# Epoch 9/12
# 92/92 [==============================] - 30s 326ms/step - loss: 0.0736 - val_loss: 0.0593
# Epoch 10/12
# 92/92 [==============================] - 24s 263ms/step - loss: 0.0528 - val_loss: 0.0268
# Epoch 11/12
# 92/92 [==============================] - 27s 296ms/step - loss: 0.0421 - val_loss: 0.0265
# Epoch 12/12
# 92/92 [==============================] - 26s 286ms/step - loss: 0.0270 - val_loss: 0.0205
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_23 (Conv2D)           (None, 263, 66, 7)        182
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 131, 33, 7)        0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 64, 29, 7)         1232
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 32, 14, 7)         0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 14, 10, 7)         1232
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 7, 5, 7)           0
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 245)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 246
# =================================================================
# Total params: 2,892
# Trainable params: 2,892
# Non-trainable params: 0
# _________________________________________________________________
# Actual model is using following hyper-parameters:
# y_stride :  2
# optimizer :  Adam
# max_pool_size :  2
# learning_rate :  0.002231516592287135
# layer_number :  3
# kernel_size :  5
# kernel_number :  7
# batch_normalization :  False
# filter_cols :  5
# batch_size :  8
# filter_cols_factor :  1
# filter_rows_factor :  1
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_generator.py:49: UserWarning: Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence class.
#   UserWarning('Using a generator with `use_multiprocessing=True`'
# Epoch 1/12
# 92/92 [==============================] - 32s 349ms/step - loss: 0.0190 - val_loss: 0.0031
# Epoch 2/12
# 92/92 [==============================] - 25s 275ms/step - loss: 0.0018 - val_loss: 0.0027
# Epoch 3/12
# 92/92 [==============================] - 26s 284ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 4/12
# 92/92 [==============================] - 26s 278ms/step - loss: 0.0020 - val_loss: 0.0023
# Epoch 5/12
# 92/92 [==============================] - 26s 280ms/step - loss: 0.0021 - val_loss: 0.0025
# Epoch 6/12
# 92/92 [==============================] - 27s 297ms/step - loss: 0.0026 - val_loss: 0.0021
# Epoch 7/12
# 92/92 [==============================] - 26s 287ms/step - loss: 0.0020 - val_loss: 0.0025
# Epoch 8/12
# 92/92 [==============================] - 26s 281ms/step - loss: 0.0021 - val_loss: 0.0025
# Epoch 9/12
# 92/92 [==============================] - 29s 316ms/step - loss: 0.0024 - val_loss: 0.0022
# Epoch 10/12
# 92/92 [==============================] - 27s 295ms/step - loss: 0.0021 - val_loss: 0.0022
# Epoch 11/12
# 92/92 [==============================] - 26s 287ms/step - loss: 0.0019 - val_loss: 0.0021
# Epoch 12/12
# 92/92 [==============================] - 26s 286ms/step - loss: 0.0023 - val_loss: 0.0014
# Tried to create a MaxPool Layer that is not possible to create, because it would lead to negative dimensions. Creation was skipped
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_26 (Conv2D)           (None, 526, 66, 7)        182
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling (None, 131, 16, 7)        0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 127, 12, 7)        1232
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling (None, 31, 3, 7)          0
# _________________________________________________________________
# flatten_11 (Flatten)         (None, 651)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 652
# =================================================================
# Total params: 2,066
# Trainable params: 2,066
# Non-trainable params: 0
# _________________________________________________________________
# Actual model is using following hyper-parameters:
# y_stride :  1
# optimizer :  Adam
# max_pool_size :  4
# learning_rate :  0.007228663045101136
# layer_number :  3
# kernel_size :  5
# kernel_number :  7
# batch_normalization :  False
# filter_cols :  5
# batch_size :  8
# filter_cols_factor :  1
# filter_rows_factor :  1
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_generator.py:49: UserWarning: Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence class.
#   UserWarning('Using a generator with `use_multiprocessing=True`'
# Epoch 1/12
# 92/92 [==============================] - 31s 333ms/step - loss: 0.0067 - val_loss: 0.0040
# Epoch 2/12
# 92/92 [==============================] - 25s 273ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 3/12
# 92/92 [==============================] - 25s 271ms/step - loss: 0.0019 - val_loss: 0.0023
# Epoch 4/12
# 92/92 [==============================] - 28s 308ms/step - loss: 0.0022 - val_loss: 0.0039
# Epoch 5/12
# 92/92 [==============================] - 27s 293ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 6/12
# 92/92 [==============================] - 26s 288ms/step - loss: 0.0026 - val_loss: 0.0021
# Epoch 7/12
# 92/92 [==============================] - 25s 267ms/step - loss: 0.0020 - val_loss: 0.0036
# Epoch 8/12
# 92/92 [==============================] - 26s 279ms/step - loss: 0.0021 - val_loss: 0.0038
# Epoch 9/12
# 92/92 [==============================] - 29s 321ms/step - loss: 0.0024 - val_loss: 0.0019
# Epoch 10/12
# 92/92 [==============================] - 25s 277ms/step - loss: 0.0023 - val_loss: 0.0032
# Epoch 11/12
# 92/92 [==============================] - 27s 293ms/step - loss: 0.0023 - val_loss: 0.0039
# Epoch 12/12
# 92/92 [==============================] - 28s 302ms/step - loss: 0.0014 - val_loss: 0.0017
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_29 (Conv2D)           (None, 522, 62, 5)        410
# _________________________________________________________________
# max_pooling2d_24 (MaxPooling (None, 130, 15, 5)        0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 130, 15, 5)        20
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 122, 7, 5)         2030
# _________________________________________________________________
# max_pooling2d_25 (MaxPooling (None, 30, 1, 5)          0
# _________________________________________________________________
# flatten_12 (Flatten)         (None, 150)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 151
# =================================================================
# Total params: 2,611
# Trainable params: 2,601
# Non-trainable params: 10
# _________________________________________________________________
# Actual model is using following hyper-parameters:
# y_stride :  1
# optimizer :  RMSProp
# max_pool_size :  4
# learning_rate :  0.0006413377163067407
# layer_number :  2
# kernel_size :  9
# kernel_number :  5
# batch_normalization :  True
# filter_cols :  5
# batch_size :  8
# filter_cols_factor :  1
# filter_rows_factor :  1
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_generator.py:49: UserWarning: Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence class.
#   UserWarning('Using a generator with `use_multiprocessing=True`'
# Epoch 1/12
# 30/92 [========>.....................] - ETA: 24s - loss: 0.02082020-04-24 22:19:30.821421: F tensorflow/stream_executor/cuda/cuda_driver.cc:257] Failed setting context: CUDA_ERROR_NOT_INITIALIZED: initialization error
# 2020-04-24 22:19:31.752728: F tensorflow/stream_executor/cuda/cuda_driver.cc:257] Failed setting context: CUDA_ERROR_NOT_INITIALIZED: initialization error
# 2020-04-24 22:19:31.940331: F tensorflow/stream_executor/cuda/cuda_driver.cc:257] Failed setting context: CUDA_ERROR_NOT_INITIALIZED: initialization error
# 2020-04-24 22:19:32.042469: F tensorflow/stream_executor/cuda/cuda_driver.cc:257] Failed setting context: CUDA_ERROR_NOT_INITIALIZED: initialization error
# 2020-04-24 22:19:32.192805: F tensorflow/stream_executor/cuda/cuda_driver.cc:257] Failed setting context: CUDA_ERROR_NOT_INITIALIZED: initialization error
# 2020-04-24 22:19:32.296001: F tensorflow/stream_executor/cuda/cuda_driver.cc:257] Failed setting context: CUDA_ERROR_NOT_INITIALIZED: initialization error
# 2020-04-24 22:19:32.525814: F tensorflow/stream_executor/cuda/cuda_driver.cc:257] Failed setting context: CUDA_ERROR_NOT_INITIALIZED: initialization error
# 2020-04-24 22:19:32.541435: F tensorflow/stream_executor/cuda/cuda_driver.cc:257] Failed setting context: CUDA_ERROR_NOT_INITIALIZED: initialization error
# 2020-04-24 22:19:32.624533: F tensorflow/stream_executor/cuda/cuda_driver.cc:257] Failed setting context: CUDA_ERROR_NOT_INITIALIZED: initialization error
# 2020-04-24 22:19:32.633100: F tensorflow/stream_executor/cuda/cuda_driver.cc:257] Failed setting context: CUDA_ERROR_NOT_INITIALIZED: initialization error
# 2020-04-24 22:19:32.634093: F tensorflow/stream_executor/cuda/cuda_driver.cc:257] Failed setting context: CUDA_ERROR_NOT_INITIALIZED: initialization error
# 2020-04-24 22:19:32.684563: F tensorflow/stream_executor/cuda/cuda_driver.cc:257] Failed setting context: CUDA_ERROR_NOT_INITIALIZED: initialization error
# 2020-04-24 22:19:32.721530: F tensorflow/stream_executor/cuda/cuda_driver.cc:257] Failed setting context: CUDA_ERROR_NOT_INITIALIZED: initialization error
# 2020-04-24 22:19:32.792557: F tensorflow/stream_executor/cuda/cuda_driver.cc:257] Failed setting context: CUDA_ERROR_NOT_INITIALIZED: initialization error
# 2020-04-24 22:19:32.813697: F tensorflow/stream_executor/cuda/cuda_driver.cc:257] Failed setting context: CUDA_ERROR_NOT_INITIALIZED: initialization error
# 2020-04-24 22:19:32.869454: F tensorflow/stream_executor/cuda/cuda_driver.cc:257] Failed setting context: CUDA_ERROR_NOT_INITIALIZED: initialization error
# /usr/local/lib/python3.6/dist-packages/keras/utils/data_utils.py:718: UserWarning: An input could not be retrieved. It could be because a worker has died.We do not have any information on the lost sample.
#   UserWarning)
# 2020-04-24 22:25:00.200771: F tensorflow/stream_executor/cuda/cuda_driver.cc:257] Failed setting context: CUDA_ERROR_NOT_INITIALIZED: initialization error
# 2020-04-24 22:27:00.204359: F tensorflow/stream_executor/cuda/cuda_driver.cc:257] Failed setting context: CUDA_ERROR_NOT_INITIALIZED: initialization error
# 41/92 [============>.................] - ETA: 10:11 - loss: 0.01582020-04-24 22:27:31.947225: F tensorflow/stream_executor/cuda/cuda_driver.cc:257] Failed setting context: CUDA_ERROR_NOT_INITIALIZED: initialization error
# ...
# Epoch 7/12
# 92/92 [==============================] - 26s 280ms/step - loss: 5.2827e-04 - val_loss: 3.8231e-04
# Epoch 8/12
# 92/92 [==============================] - 25s 268ms/step - loss: 0.0027 - val_loss: 0.0074
# Epoch 9/12
# 92/92 [==============================] - 27s 290ms/step - loss: 8.1929e-04 - val_loss: 0.0018
# Epoch 10/12
# 92/92 [==============================] - 28s 308ms/step - loss: 3.1160e-04 - val_loss: 0.0177
# Epoch 11/12
# 92/92 [==============================] - 25s 276ms/step - loss: 5.9725e-04 - val_loss: 0.0119
# Epoch 12/12
# 92/92 [==============================] - 27s 295ms/step - loss: 4.6180e-04 - val_loss: 0.0040
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_31 (Conv2D)           (None, 264, 68, 7)        70
# _________________________________________________________________
# max_pooling2d_26 (MaxPooling (None, 88, 22, 7)         0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 88, 22, 7)         28
# _________________________________________________________________
# conv2d_32 (Conv2D)           (None, 43, 20, 7)         448
# _________________________________________________________________
# max_pooling2d_27 (MaxPooling (None, 14, 6, 7)          0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 14, 6, 7)          28
# _________________________________________________________________
# conv2d_33 (Conv2D)           (None, 6, 4, 7)           448
# _________________________________________________________________
# max_pooling2d_28 (MaxPooling (None, 2, 1, 7)           0
# _________________________________________________________________
# flatten_13 (Flatten)         (None, 14)                0
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 15
# =================================================================
# Total params: 1,037
# Trainable params: 1,009
# Non-trainable params: 28
# _________________________________________________________________
# Actual model is using following hyper-parameters:
# y_stride :  2
# optimizer :  SGD
# max_pool_size :  3
# learning_rate :  0.0002831804172327656
# layer_number :  3
# kernel_size :  3
# kernel_number :  7
# batch_normalization :  True
# filter_cols :  5
# batch_size :  8
# filter_cols_factor :  1
# filter_rows_factor :  1
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_generator.py:49: UserWarning: Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence class.
#   UserWarning('Using a generator with `use_multiprocessing=True`'
# Epoch 1/12
# 92/92 [==============================] - 34s 368ms/step - loss: 0.0694 - val_loss: 0.1934
# Epoch 2/12
# 92/92 [==============================] - 24s 262ms/step - loss: 0.0591 - val_loss: 0.2450
# Epoch 3/12
# 92/92 [==============================] - 24s 266ms/step - loss: 0.0658 - val_loss: 0.1641
# Epoch 4/12
# 92/92 [==============================] - 27s 298ms/step - loss: 0.0670 - val_loss: 0.1285
# Epoch 5/12
# 92/92 [==============================] - 27s 288ms/step - loss: 0.0694 - val_loss: 0.0675
# Epoch 6/12
# 92/92 [==============================] - 26s 286ms/step - loss: 0.0712 - val_loss: 0.1270
# Epoch 7/12
# 92/92 [==============================] - 26s 284ms/step - loss: 0.0700 - val_loss: 0.1653
# Epoch 8/12
# 92/92 [==============================] - 28s 302ms/step - loss: 0.0562 - val_loss: 0.1619
# Epoch 9/12
# 92/92 [==============================] - 26s 278ms/step - loss: 0.0350 - val_loss: 0.0921
# Epoch 10/12
# 92/92 [==============================] - 26s 286ms/step - loss: 0.0522 - val_loss: 0.0122
# Epoch 11/12
# 92/92 [==============================] - 26s 284ms/step - loss: 0.0712 - val_loss: 0.0293
# Epoch 12/12
# 92/92 [==============================] - 27s 291ms/step - loss: 0.0933 - val_loss: 0.0430
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_34 (Conv2D)           (None, 263, 66, 3)        78
# _________________________________________________________________
# max_pooling2d_29 (MaxPooling (None, 65, 16, 3)         0
# _________________________________________________________________
# conv2d_35 (Conv2D)           (None, 31, 12, 3)         228
# _________________________________________________________________
# max_pooling2d_30 (MaxPooling (None, 7, 3, 3)           0
# _________________________________________________________________
# flatten_14 (Flatten)         (None, 63)                0
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 64
# =================================================================
# Total params: 370
# Trainable params: 370
# Non-trainable params: 0
# _________________________________________________________________
# Actual model is using following hyper-parameters:
# y_stride :  2
# optimizer :  SGD
# max_pool_size :  4
# learning_rate :  0.00035656991930916514
# layer_number :  2
# kernel_size :  5
# kernel_number :  3
# batch_normalization :  False
# filter_cols :  5
# batch_size :  8
# filter_cols_factor :  1
# filter_rows_factor :  1
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_generator.py:49: UserWarning: Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence class.
#   UserWarning('Using a generator with `use_multiprocessing=True`'
# Epoch 1/12
# 92/92 [==============================] - 33s 364ms/step - loss: 0.2235 - val_loss: 0.2151
# Epoch 2/12
# 92/92 [==============================] - 25s 272ms/step - loss: 0.2454 - val_loss: 0.2313
# Epoch 3/12
# 92/92 [==============================] - 26s 287ms/step - loss: 0.2426 - val_loss: 0.2481
# Epoch 4/12
# 92/92 [==============================] - 25s 276ms/step - loss: 0.2469 - val_loss: 0.2066
# Epoch 5/12
# 92/92 [==============================] - 27s 296ms/step - loss: 0.2398 - val_loss: 0.2319
# Epoch 6/12
# 92/92 [==============================] - 27s 294ms/step - loss: 0.2323 - val_loss: 0.2545
# Epoch 7/12
# 92/92 [==============================] - 27s 298ms/step - loss: 0.2309 - val_loss: 0.2353
# Epoch 8/12
# 92/92 [==============================] - 28s 304ms/step - loss: 0.2356 - val_loss: 0.2278
# Epoch 9/12
# 92/92 [==============================] - 26s 288ms/step - loss: 0.2360 - val_loss: 0.2517
# Epoch 10/12
# 92/92 [==============================] - 27s 289ms/step - loss: 0.2291 - val_loss: 0.2166
# Epoch 11/12
# 92/92 [==============================] - 25s 270ms/step - loss: 0.2329 - val_loss: 0.2448
# Epoch 12/12
# 92/92 [==============================] - 27s 295ms/step - loss: 0.2253 - val_loss: 0.2305
# Tried to create a MaxPool Layer that is not possible to create, because it would lead to negative dimensions. Creation was skipped
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_36 (Conv2D)           (None, 527, 67, 5)        85
# _________________________________________________________________
# max_pooling2d_31 (MaxPooling (None, 131, 16, 5)        0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 131, 16, 5)        20
# _________________________________________________________________
# conv2d_37 (Conv2D)           (None, 128, 13, 5)        405
# _________________________________________________________________
# max_pooling2d_32 (MaxPooling (None, 32, 3, 5)          0
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 32, 3, 5)          20
# _________________________________________________________________
# flatten_15 (Flatten)         (None, 480)               0
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 481
# =================================================================
# Total params: 1,011
# Trainable params: 991
# Non-trainable params: 20
# _________________________________________________________________
# Actual model is using following hyper-parameters:
# y_stride :  1
# optimizer :  SGD
# max_pool_size :  4
# learning_rate :  0.0001064073451061438
# layer_number :  3
# kernel_size :  4
# kernel_number :  5
# batch_normalization :  True
# filter_cols :  5
# batch_size :  8
# filter_cols_factor :  1
# filter_rows_factor :  1
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_generator.py:49: UserWarning: Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence class.
#   UserWarning('Using a generator with `use_multiprocessing=True`'
# Epoch 1/12
# 92/92 [==============================] - 32s 346ms/step - loss: 0.1932 - val_loss: 0.1757
# Epoch 2/12
# 92/92 [==============================] - 25s 275ms/step - loss: 0.2016 - val_loss: 0.1397
# Epoch 3/12
# 92/92 [==============================] - 27s 291ms/step - loss: 0.2012 - val_loss: 0.1338
# Epoch 4/12
# 92/92 [==============================] - 27s 293ms/step - loss: 0.1748 - val_loss: 0.1119
# Epoch 5/12
# 92/92 [==============================] - 25s 269ms/step - loss: 0.1924 - val_loss: 0.0954
# Epoch 6/12
# 92/92 [==============================] - 26s 287ms/step - loss: 0.1465 - val_loss: 0.0958
# Epoch 7/12
# 92/92 [==============================] - 27s 289ms/step - loss: 0.1570 - val_loss: 0.1659
# Epoch 8/12
# 92/92 [==============================] - 28s 299ms/step - loss: 0.1519 - val_loss: 0.1166
# Epoch 9/12
# 92/92 [==============================] - 27s 297ms/step - loss: 0.1416 - val_loss: 0.0602
# Epoch 10/12
# 92/92 [==============================] - 26s 285ms/step - loss: 0.1902 - val_loss: 0.1808
# Epoch 11/12
# 92/92 [==============================] - 25s 270ms/step - loss: 0.1942 - val_loss: 0.1467
# Epoch 12/12
# 92/92 [==============================] - 26s 285ms/step - loss: 0.1910 - val_loss: 0.2007
# Model: "sequential_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_39 (Conv2D)           (None, 523, 63, 6)        390
# _________________________________________________________________
# max_pooling2d_33 (MaxPooling (None, 174, 21, 6)        0
# _________________________________________________________________
# conv2d_40 (Conv2D)           (None, 167, 14, 6)        2310
# _________________________________________________________________
# max_pooling2d_34 (MaxPooling (None, 55, 4, 6)          0
# _________________________________________________________________
# flatten_16 (Flatten)         (None, 1320)              0
# _________________________________________________________________
# dense_16 (Dense)             (None, 1)                 1321
# =================================================================
# Total params: 4,021
# Trainable params: 4,021
# Non-trainable params: 0
# _________________________________________________________________
# Actual model is using following hyper-parameters:
# y_stride :  1
# optimizer :  Adam
# max_pool_size :  3
# learning_rate :  0.0004260549952308603
# layer_number :  2
# kernel_size :  8
# kernel_number :  6
# batch_normalization :  False
# filter_cols :  5
# batch_size :  8
# filter_cols_factor :  1
# filter_rows_factor :  1
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_generator.py:49: UserWarning: Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence class.
#   UserWarning('Using a generator with `use_multiprocessing=True`'
# Epoch 1/12
# 92/92 [==============================] - 32s 346ms/step - loss: 0.0435 - val_loss: 0.0024
# Epoch 2/12
# 92/92 [==============================] - 27s 291ms/step - loss: 0.0017 - val_loss: 0.0037
# Epoch 3/12
# 92/92 [==============================] - 25s 271ms/step - loss: 0.0015 - val_loss: 8.3195e-04
# Epoch 4/12
# 92/92 [==============================] - 26s 286ms/step - loss: 0.0015 - val_loss: 7.1216e-04
# Epoch 5/12
# 92/92 [==============================] - 26s 284ms/step - loss: 0.0016 - val_loss: 0.0024
# Epoch 6/12
# 92/92 [==============================] - 27s 288ms/step - loss: 0.0019 - val_loss: 0.0010
# Epoch 7/12
# 92/92 [==============================] - 25s 277ms/step - loss: 6.5738e-04 - val_loss: 1.9387e-04
# Epoch 8/12
# 92/92 [==============================] - 26s 282ms/step - loss: 3.7411e-04 - val_loss: 9.3775e-05
# Epoch 9/12
# 92/92 [==============================] - 25s 277ms/step - loss: 3.3640e-04 - val_loss: 1.5012e-04
# Epoch 10/12
# 92/92 [==============================] - 26s 288ms/step - loss: 2.8738e-04 - val_loss: 3.5866e-04
# Epoch 11/12
# 92/92 [==============================] - 26s 281ms/step - loss: 2.8200e-04 - val_loss: 3.4450e-04
# Epoch 12/12
# 92/92 [==============================] - 30s 321ms/step - loss: 1.8607e-04 - val_loss: 0.0011
# Model: "sequential_17"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_41 (Conv2D)           (None, 528, 68, 6)        60
# _________________________________________________________________
# max_pooling2d_35 (MaxPooling (None, 264, 34, 6)        0
# _________________________________________________________________
# conv2d_42 (Conv2D)           (None, 262, 32, 6)        330
# _________________________________________________________________
# max_pooling2d_36 (MaxPooling (None, 131, 16, 6)        0
# _________________________________________________________________
# conv2d_43 (Conv2D)           (None, 129, 14, 6)        330
# _________________________________________________________________
# max_pooling2d_37 (MaxPooling (None, 64, 7, 6)          0
# _________________________________________________________________
# flatten_17 (Flatten)         (None, 2688)              0
# _________________________________________________________________
# dense_17 (Dense)             (None, 1)                 2689
# =================================================================
# Total params: 3,409
# Trainable params: 3,409
# Non-trainable params: 0
# _________________________________________________________________
# Actual model is using following hyper-parameters:
# y_stride :  1
# optimizer :  Adam
# max_pool_size :  2
# learning_rate :  0.011420041530456216
# layer_number :  3
# kernel_size :  3
# kernel_number :  6
# batch_normalization :  False
# filter_cols :  5
# batch_size :  8
# filter_cols_factor :  1
# filter_rows_factor :  1
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_generator.py:49: UserWarning: Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence class.
#   UserWarning('Using a generator with `use_multiprocessing=True`'
# Epoch 1/12
# 92/92 [==============================] - 32s 347ms/step - loss: 0.0051 - val_loss: 0.0031
# Epoch 2/12
# 92/92 [==============================] - 27s 293ms/step - loss: 0.0015 - val_loss: 0.0041
# Epoch 3/12
# 92/92 [==============================] - 26s 285ms/step - loss: 0.0021 - val_loss: 0.0014
# Epoch 4/12
# 92/92 [==============================] - 25s 276ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 5/12
# 34/92 [==========>...................] - ETA: 15s - loss: 0.0022

# %%
# use this code to prevent colab from disconnecting during longer training times in javascript console window
function ClickConnect(){
    console.log("Clicked on connect button"); 
    document.querySelector("colab-connect-button").click()
}
setInterval(ClickConnect,60000)
