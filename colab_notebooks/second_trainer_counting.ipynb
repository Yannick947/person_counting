# %%
# %cd ..
# !nvidia-smi
# Out:
# Wed Sep  9 09:45:38 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.66       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0    24W / 300W |      0MiB / 16130MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !git clone https://github.com/Yannick947/pcds_detected.git
# Out:
# Cloning into 'pcds_detected'...
# remote: Enumerating objects: 3060, done.
# remote: Counting objects: 100% (3060/3060), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 3060 (delta 3028), reused 3058 (delta 3026), pack-reused 0
# Receiving objects: 100% (3060/3060), 10.65 MiB | 12.92 MiB/s, done.
# Resolving deltas: 100% (3028/3028), done.
# Checking out files: 100% (3072/3072), done.

# %%
# !pip install gdown
# !pip install tensorflow-gpu==2.2 --user
# !pip install keras==2.3.1
# Out:
# ...
#      |████████████████████████████████| 516.2MB 32kB/s
# ...
#      |████████████████████████████████| 3.0MB 66.3MB/s
# ...
#      |████████████████████████████████| 460kB 63.1MB/s
# ...
# ERROR: tensorflow 2.3.0 has requirement tensorboard<3,>=2.3.0, but you'll have tensorboard 2.2.2 which is incompatible.
# ERROR: tensorflow 2.3.0 has requirement tensorflow-estimator<2.4.0,>=2.3.0, but you'll have tensorflow-estimator 2.2.0 which is incompatible.
# ...
#   WARNING: The script tensorboard is installed in '/root/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts estimator_ckpt_converter, saved_model_cli, tensorboard, tf_upgrade_v2, tflite_convert, toco and toco_from_protos are installed in '/root/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...

# %% [markdown]
# # Training

# %%
from datetime import datetime
import random
logdir = '/content/drive/My\ Drive/person_counting/tensorboard/cnn_regression/warm_start/t2_{}'.format(datetime.now().strftime("%Y-%m-%d-%H-%M-%S"))
top_path = '/content/pcds_detected/'
snap = '/content/drive/My\ Drive/person_counting/tensorboard/cnn_regression/cold_start/best'

# %%
# %cd /content/drive/My\ Drive/
# Out:
# /content/drive/My Drive

# %%
for i in range(100):
    augmentation_factor = random.randint(1,15) / 20
    print(augmentation_factor)
    # !python -m person_counting.models.cnn_regression  --topdir-log {logdir}\
                                                      --warm-start $snap\
                                                      --augmentation-factor $augmentation_factor\
                                                      --n-runs 1\
                                                      --schedule-step 15\
                                                      --filter-hour-above 20\
                                                      --top-path {top_path}\
                                                      --epochs 120\
                                                      --supercharge-crowdeds\
# Out:
# Epoch 00019: val_mae_rescaled did not improve from 0.14032
#
# Epoch 00019: val_mae_rescaled did not improve from 0.14032
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.0002994119713548571.
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.0002994119713548571.
# /usr/local/lib/python3.6/dist-packages/keras/utils/data_utils.py:616: UserWarning: The input 198 could not be retrieved. It could be because a worker has died.
#   UserWarning)
# /usr/local/lib/python3.6/dist-packages/keras/utils/data_utils.py:616: UserWarning: The input 198 could not be retrieved. It could be because a worker has died.
#   UserWarning)
#
# Epoch 00020: val_mae_rescaled did not improve from 0.14032
#
# Epoch 00020: val_mae_rescaled did not improve from 0.14032
#
# Epoch 00021: LearningRateScheduler setting learning rate to 0.0002994119713548571.
#
# Epoch 00021: LearningRateScheduler setting learning rate to 0.0002994119713548571.

# %%
# use this code to prevent colab from disconnecting during longer training times in javascript console window
function ClickConnect(){
    console.log("Clicked on connect button"); 
    document.querySelector("colab-connect-button").click()
}
setInterval(ClickConnect,60000)
