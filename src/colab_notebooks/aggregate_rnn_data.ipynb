# %%
import pandas as pd
import numpy as np
import matplotlib
import seaborn as sns
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

# %%
df = pd.read_csv('C:/Users/Yannick/OneDrive/Dokumente/Studium/Masterarbeit/Ausarbeitung/98_images/source/hparams_table_counting_best60_cold_new.csv')
df.head()
# Out:
#    filter_cols_upper  units  filter_category_noisy  schedule_step  \
# 0                0.0   13.0                  False           40.0
# 1                0.0   12.0                  False           40.0
# 2                0.0   13.0                  False           40.0
# 3                0.0   12.0                  False           40.0
# 4                0.0   12.0                  False           40.0
#
#    layer_number squeeze_method  filter_hour_above  number_params  batch_size  \
# 0           5.0        squeeze               20.0        11648.0        16.0
# 1           5.0        squeeze               20.0        10137.0        32.0
# 2           5.0       1x1_conv               20.0         9011.0        32.0
# 3           5.0       1x1_conv               20.0         9168.0        32.0
# 4           5.0       1x1_conv               20.0         8828.0        16.0
#
#    regularization          ...            pool_size_x  Recurrent_Celltype  \
# ...

# %%
df_rnn = df[['units', 'Recurrent_Celltype', 'epoch_epoch_mae_rescaled_max']]

# %%
aggregated_mae = df_rnn.groupby(['units', 'Recurrent_Celltype']).mean()
aggregated_mae.to_csv('C:/Users/Yannick/OneDrive/Dokumente/Studium/Masterarbeit/Ausarbeitung/98_images/source/rnn_aggregation.csv')
